# %%
## Q1: What are the Probability Mass Function (PMF) and Probability Density Function (PDF)? Explain with an example.
'''(i) Probability mass function is the probability distribution of a discrete random variable, and provides the possible values and their associated probabilities.
eg:
Bernoulli distribution: ber(p) , is used to model an experiment with only two possible outcomes. The two outcomes are often encoded as 1 and 0.
An example of the Bernoulli distribution is tossing a coin. 
eg:
Consider f(x) = x + 3, when 1 < x ≤ 3. We have to find P(2 < X < 3). Integrating x + 3 within the limits 2 and 3 gives the answer 5.5.'''
# Out:
# '(i) Probability mass function is the probability distribution of a discrete random variable, and provides the possible values and their associated probabilities.\neg:\nBernoulli distribution: ber(p) , is used to model an experiment with only two possible outcomes. The two outcomes are often encoded as 1 and 0.\nAn example of the Bernoulli distribution is tossing a coin. \neg:\nConsider f(x) = x + 3, when 1 < x ≤ 3. We have to find P(2 < X < 3). Integrating x + 3 within the limits 2 and 3 gives the answer 5.5.'

# %%
## Q2: What is Cumulative Density Function (CDF)? Explain with an example. Why CDF is used?
'''A cumulative distribution function (CDF) describes the probabilities of a random variable having values less than or equal to x. 
It is a cumulative function because it sums the total likelihood up to that point. Its output always ranges between 0 and 1.
CDF(x) = P(X ≤ x)
Where X is the random variable, and x is a specific value. The CDF gives us the probability that the random variable X is less than or equal to x. 
These functions are non-decreasing. As x increases, the likelihood can either increase or stay constant, but it can’t decrease.'
Eg: Consider the height of an adult male in India We can use the cumulative distribution function to find the probability that a person is less than or equal to 6 feet tall.
Uses:
The concept of CDF is used in two ways.
(i) Finding the frequency of occurrence of values for the given phenomena using cumulative frequency analysis.
(ii) To derive some simple statistics properties, by using an empirical distribution function, that uses a formal direct estimate of CDFs.'''
# Out:
# "A cumulative distribution function (CDF) describes the probabilities of a random variable having values less than or equal to x. \nIt is a cumulative function because it sums the total likelihood up to that point. Its output always ranges between 0 and 1.\nCDF(x) = P(X ≤ x)\nWhere X is the random variable, and x is a specific value. The CDF gives us the probability that the random variable X is less than or equal to x. \nThese functions are non-decreasing. As x increases, the likelihood can either increase or stay constant, but it can’t decrease.'\nEg: Consider the height of an adult male in India We can use the cumulative distribution function to find the probability that a person is less than or equal to 6 feet tall.\nUses:\nThe concept of CDF is used in two ways.\n(i) Finding the frequency of occurrence of values for the given phenomena using cumulative frequency analysis.\n(ii) To derive some simple statistics properties, by using an empirical distribution function, that uses a 
# ...

# %%
## Q3: What are some examples of situations where the normal distribution might be used as a model? Explain how the parameters of the normal distribution relate to the shape of the distribution.
'''Examples of situations where the normal distribution might be used as a model are in calculating the following values
(i) Birthweight of Babies
(ii) Height of Males/Females
(iii) Shoe Sizes
(iv) Blood Pressure
The two main parameters of a (normal) distribution are the mean and standard deviation. 
The parameters determine the shape and probabilities of the distribution. The shape of the distribution changes as the parameter values change.
(i) In a normal distribution graph, the mean defines the location of the peak, and most of the data points are clustered around the mean. 
Any changes made to the value of the mean move the curve either to the left or right along the X-axis.
(ii) The standard deviation determines the width of the curve, and it tightens or expands the width of the distribution along the x-axis. 
Typically, a small standard deviation relative to the mean produces a steep curve, while a large standard deviation relative to the mean produces a flatter curve.'''
# Out:
# 'Examples of situations where the normal distribution might be used as a model are in calculating the following values\n(i) Birthweight of Babies\n(ii) Height of Males/Females\n(iii) Shoe Sizes\n(iv) Blood Pressure\nThe two main parameters of a (normal) distribution are the mean and standard deviation. \nThe parameters determine the shape and probabilities of the distribution. The shape of the distribution changes as the parameter values change.\n(i) In a normal distribution graph, the mean defines the location of the peak, and most of the data points are clustered around the mean. \nAny changes made to the value of the mean move the curve either to the left or right along the X-axis.\n(ii) The standard deviation determines the width of the curve, and it tightens or expands the width of the distribution along the x-axis. \nTypically, a small standard deviation relative to the mean produces a steep curve, while a large standard deviation relative to the mean produces a flatter curve.'
# ...

# %%
## Q4: Explain the importance of Normal Distribution. Give a few real-life examples of Normal Distribution.
'''The normal distribution is the most important probability distribution in statistics because it fits many natural phenomena. 
For example, heights, blood pressure, measurement error, and IQ scores follow the normal distribution. It is also known as the Gaussian distribution and the bell curve.
A normal distribution is a distribution that is solely dependent on two parameters of the data set: mean and the standard deviation of the sample.
Mean is the centre of the curve. This is the highest point of the curve as most of the points are at the mean. There is an equal number of points on each side of the curve. 
The centre of the curve has the greatest number of points. This allows us to easily estimate how volatile a variable is and given a confidence level, what it's likely value is going to be.
The normal distribution is the proper term for a probability bell curve.
In a normal distribution the mean is zero and the standard deviation is 1. It has zero skew and a kurtosis of 3.'''
# Out:
# "The normal distribution is the most important probability distribution in statistics because it fits many natural phenomena. \nFor example, heights, blood pressure, measurement error, and IQ scores follow the normal distribution. It is also known as the Gaussian distribution and the bell curve.\nA normal distribution is a distribution that is solely dependent on two parameters of the data set: mean and the standard deviation of the sample.\nMean is the centre of the curve. This is the highest point of the curve as most of the points are at the mean. There is an equal number of points on each side of the curve. \nThe centre of the curve has the greatest number of points. This allows us to easily estimate how volatile a variable is and given a confidence level, what it's likely value is going to be.\nThe normal distribution is the proper term for a probability bell curve.\nIn a normal distribution the mean is zero and the standard deviation is 1. It has zero skew and a kurtosis of 3."
# ...

# %%
## Q5: What is Bernaulli Distribution? Give an Example. What is the difference between Bernoulli Distribution and Binomial Distribution?
'''A random variable follows a Bernoulli distribution if it only has two possible outcomes: 0 or 1.
For example, suppose we flip a coin one time. Let the probability that it lands on heads be p. This means the probability that it lands on tails is 1-p.
In this case, random variable X  can only take on two possible values.
Now, if we flip a coin multiple times then the sum of the Bernoulli random variables will follow a Binomial distribution.
For example, suppose we flip a coin 5 times and we want to know the probability of obtaining heads k times. We would say that the random variable X follows a Binomial distribution.
Difference between Bernoulli Distribution and Binomial Distribution:
(i) Bernoulli distribution deals with the data which only has 1 trial & only 2 possible outcomes.
Binomial Distribution is the collection of Bernoulli trials for the same event, i.e., it contains more than 1 Bernoulli event for the same scenario for which the Bernoulli trial is calculated.
(ii) In order for a random variable to follow a Binomial distribution, the probability of “success” in each Bernoulli trial must be equal and independent.'''
# Out:
# 'A random variable follows a Bernoulli distribution if it only has two possible outcomes: 0 or 1.\nFor example, suppose we flip a coin one time. Let the probability that it lands on heads be p. This means the probability that it lands on tails is 1-p.\nIn this case, random variable X  can only take on two possible values.\nNow, if we flip a coin multiple times then the sum of the Bernoulli random variables will follow a Binomial distribution.\nFor example, suppose we flip a coin 5 times and we want to know the probability of obtaining heads k times. We would say that the random variable X follows a Binomial distribution.\nDifference between Bernoulli Distribution and Binomial Distribution:\n(i) Bernoulli distribution deals with the data which only has 1 trial & only 2 possible outcomes.\nBinomial Distribution is the collection of Bernoulli trials for the same event, i.e., it contains more than 1 Bernoulli event for the same scenario for which the Bernoulli trial is calculated.\n(ii) 
# ...

# %%
'''Q6. Consider a dataset with a mean of 50 and a standard deviation of 10. If we assume that the dataset is normally distributed, what is the probability that a randomly selected observation will be greater
than 60? Use the appropriate formula and show your calculations.'''
# Out:
# 'Q6. Consider a dataset with a mean of 50 and a standard deviation of 10. If we assume that the dataset is normally distributed, what is the probability that a randomly selected observation will be greater\nthan 60? Use the appropriate formula and show your calculations.'

# %% [markdown]
# ![P-value.jpg](data:image/jpeg;base64,...)

# %%
## Q7: Explain uniform Distribution with an example.
'''The uniform distribution is concerned with events that are equally likely to occur. That means all outcomes have the equal chance of happening in the uniform distribution. 
For example, rolling a fair die will produce a uniform distribution, because each side from 1 to 6 has equal probability of facing up. 
The uniform distribution can be discrete or continuous. In a discrete uniform distribution, outcomes are discrete numbers such as non-negative integers, and in a continuous distribution, outcomes are continuous and infinite.'''
# Out:
# 'The uniform distribution is concerned with events that are equally likely to occur. That means all outcomes have the equal chance of happening in the uniform distribution. \nFor example, rolling a fair die will produce a uniform distribution, because each side from 1 to 6 has equal probability of facing up. \nThe uniform distribution can be discrete or continuous. In a discrete uniform distribution, outcomes are discrete numbers such as non-negative integers, and in a continuous distribution, outcomes are continuous and infinite.'

# %%
## Q8: What is the z score? State the importance of the z score.
'''A measure of how many standard deviations below or above the population mean a raw score is called z score. 
It will be positive if the value lies above the mean and negative if it lies below the mean. It is also known as standard score. 
t indicates how many standard deviations an entity is, from the mean. In order to use a z-score, the mean μ and also the population standard deviation σ should be known. 
A z score helps to calculate the probability of a score occurring within a standard normal distribution. It also enables us to compare two scores that are from different samples.
Importance of the z score:
(i) To understand How an Observation Fits into a Distribution
(ii) To Compare Different Types of Variables
(iii) To Detect Outliers
(iv) Using Z-tables to calculate Probabilities and Percentiles
(v) The z-score of a number tell us the number’s “relative standing” in a data set. Relative standing is a measure of how many standard deviations above, or below, a data value is from the mean.'''
# Out:
# 'A measure of how many standard deviations below or above the population mean a raw score is called z score. \nIt will be positive if the value lies above the mean and negative if it lies below the mean. It is also known as standard score. \nt indicates how many standard deviations an entity is, from the mean. In order to use a z-score, the mean μ and also the population standard deviation σ should be known. \nA z score helps to calculate the probability of a score occurring within a standard normal distribution. It also enables us to compare two scores that are from different samples.\nImportance of the z score:\n(i) To understand How an Observation Fits into a Distribution\n(ii) To Compare Different Types of Variables\n(iii) To Detect Outliers\n(iv) Using Z-tables to calculate Probabilities and Percentiles\n(v) The z-score of a number tell us the number’s “relative standing” in a data set. Relative standing is a measure of how many standard deviations above, or below, a data value 
# ...

# %%
## Q9: What is Central Limit Theorem? State the significance of the Central Limit Theorem.
'''The central limit theorem states that if you take sufficiently large samples from a population, the samples’ means will be normally distributed, even if the population isn’t normally distributed.
It relies on the concept of a sampling distribution, which is the probability distribution of a statistic for a large number of samples taken from a population
Significance of the Central Limit Theorem:
(i) This theorem allows you to simplify problems in statistics by allowing you to work with a distribution that is approximately normal.
(ii) It enables to reasonably accurate probabilities to be determined for events involving sample average when the sample size is large enough regardless of the distribution of original values.'''
# Out:
# 'The central limit theorem states that if you take sufficiently large samples from a population, the samples’ means will be normally distributed, even if the population isn’t normally distributed.\nIt relies on the concept of a sampling distribution, which is the probability distribution of a statistic for a large number of samples taken from a population\nSignificance of the Central Limit Theorem:\n(i) This theorem allows you to simplify problems in statistics by allowing you to work with a distribution that is approximately normal.\n(ii) It enables to reasonably accurate probabilities to be determined for events involving sample average when the sample size is large enough regardless of the distribution of original values.'

# %%
## Q10: State the assumptions of the Central Limit Theorem.
'''In order to apply the central limit theorem, there are four conditions that must be met:
1. Randomization: The data must be sampled randomly such that every member in a population has an equal probability of being selected to be in the sample.
2. Independence: The sample values must be independent of each other.
3. The 10% Condition: When the sample is drawn without replacement, the sample size should be no larger than 10% of the population.
4. Large Sample Condition: The sample size needs to be sufficiently large.'''
# Out:
# 'In order to apply the central limit theorem, there are four conditions that must be met:\n1. Randomization: The data must be sampled randomly such that every member in a population has an equal probability of being selected to be in the sample.\n2. Independence: The sample values must be independent of each other.\n3. The 10% Condition: When the sample is drawn without replacement, the sample size should be no larger than 10% of the population.\n4. Large Sample Condition: The sample size needs to be sufficiently large.'
